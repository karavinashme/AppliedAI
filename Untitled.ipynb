# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
hman=pd.read_csv('haberman.csv')

# %%
hman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     306 non-null    int64
#  1   year    306 non-null    int64
#  2   nodes   306 non-null    int64
#  3   status  306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
hman.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
hman.shape
# Out:
# (306, 4)

# %%
hman.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
hman['status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
pic=pd.DataFrame   (hman['status'].value_counts())
pic['status_cd']=pic.index
pic.rename(columns={'status':'count'},inplace=True)
plt.pie(pic['count'],labels=pic['status_cd'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## 2D scatter

# %%
hman.plot(kind='scatter', x='age', y='year');
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(hman,hue='status',size=4).map(plt.scatter, "age", "year").add_legend()

# %%
plt.close()

# %%
sns.relplot(x='age', y='year',data=hman, hue='status').add_legend()

# %%
#plt.close()
sns.set_style("whitegrid")
sns.pairplot(hman,hue="status")
plt.show()

# %%
plt.close()
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
import numpy as np
iris_setosa = iris.loc[iris["species"] == "Iris-setosa"];
iris_virginica = iris.loc[iris["species"] == "Iris-virginica"];
iris_versicolor = iris.loc[iris["species"] == "Iris-versicolor"];
#print(iris_setosa["petal_length"])
plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'x')

plt.show()

# %%
hman.describe()
# Out:
#               age        year       nodes      status
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %%
plt.close()
hman_st1=hman.loc[hman["status"]==1]
hman_st2=hman.loc[hman["status"]==2]
plt.plot(hman_st1["age"], np.zeros_like(hman_st1["age"]), '.')
plt.plot(hman_st2["age"], np.zeros_like(hman_st2["age"]), 'x')
plt.show()

# %%
plt.plot(hman_st1["year"], np.zeros_like(hman_st1["year"]), 'o')
plt.plot(hman_st2["year"], np.zeros_like(hman_st2["year"]), 'x')

# %%
plt.plot(hman_st1["nodes"], np.zeros_like(hman_st1["nodes"]), 'o')
plt.plot(hman_st2["nodes"], np.zeros_like(hman_st2["nodes"]), 'x')

# %%
sns.FacetGrid(hman, hue='status',size=5) \
.map(sns.distplot, "nodes").add_legend()
plt.show()
# Out:
# C:\Users\AVKAR\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(hman, hue="status", size=5) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();
# Out:
# C:\Users\AVKAR\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
hman.describe()
# Out:
#               age        year       nodes      status
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %%
hman_st1.describe()
# Out:
#               age        year       nodes  status
# count  225.000000  225.000000  225.000000   225.0
# mean    52.017778   62.862222    2.791111     1.0
# std     11.012154    3.222915    5.870318     0.0
# min     30.000000   58.000000    0.000000     1.0
# 25%     43.000000   60.000000    0.000000     1.0
# 50%     52.000000   63.000000    0.000000     1.0
# 75%     60.000000   66.000000    3.000000     1.0
# max     77.000000   69.000000   46.000000     1.0

# %%
hman_st2.describe()
# Out:
#              age       year      nodes  status
# count  81.000000  81.000000  81.000000    81.0
# mean   53.679012  62.827160   7.456790     2.0
# std    10.167137   3.342118   9.185654     0.0
# min    34.000000  58.000000   0.000000     2.0
# 25%    46.000000  59.000000   1.000000     2.0
# 50%    53.000000  63.000000   4.000000     2.0
# 75%    61.000000  65.000000  11.000000     2.0
# max    83.000000  69.000000  52.000000     2.0

# %%
sns.boxplot(x='status',y='nodes',data=hman)

# %%
sns.violinplot(x='status',y='nodes',data=hman)
plt.show()

# %%
sns.jointplot(x='year',y='nodes',data=hman,kind='kde' )

# %%
sns.boxplot(y='year',x='status', data=hman)

# %%
plt.figure(figsize =(10, 7))
plt.boxplot(hman['nodes'])
plt.show()
